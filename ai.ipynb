# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
load_dotenv()
# Out:
# True

# %%
MYSQL_URI = os.getenv("MYSQL_URI")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
engine = create_engine(MYSQL_URI)

# %%
leads = pd.read_sql("SELECT * FROM Leads", engine)

# %%
leads[leads['Email'].isna()]
# Out:
#       LeadID  AccountID  ClientID                           Position  \
# 165    18250       5180    100000     Director of Technical Services
# 175    18750       5670    100000  Director - Information Technology
# 257    22850       7390    100000     Director Of Technical Services
# 305    25250       8010    100000                     Director of IT
# 589    39450      13200    100000     Group Chief Technology Officer
# ...      ...        ...       ...                                ...
# 1534   86700      13170    100000                 Technical Director
# 1535   86750      13170    100000                  Technical manager
# 1536   86800      13180    100000                  Head of Solutions
# 1537   86850      13180    100000                    Leiter Group IT
# 1538   86900      13180    100000           Chief Technology Officer
#
#       FirstName    LastName Email               CompanyName  \
# 165                          None              Drury Hotels
# 175                          None                    Oakley
# 257                          None  KARL STORZ United States
# 305                          None            Composites One
# 589      Hugues      Crepin  None             Curium Pharma
# ...         ...         ...   ...                       ...
# 1534     Pirkle        Mark  None               Voith Hydro
# 1535     Gunnar      Bakken  None               Voith Hydro
# 1536      Kamil           K  None                    TRILUX
# 1537     Stefan  Magerstedt  None                    TRILUX
# 1538  Sebastian    Traegner  None                    TRILUX
#
#                       CreatedBy DateCreated Owner Status  FollowUp
# 165   haris.saif@erp-center.com  2024-09-14  None   Open         0
# 175   haris.saif@erp-center.com  2024-09-14  None   Open         0
# 257   haris.saif@erp-center.com  2024-09-14  None   Open         0
# 305   haris.saif@erp-center.com  2024-09-14  None   Open         0
# 589   haris.saif@erp-center.com  2024-09-14  None   Open         0
# ...                         ...         ...   ...    ...       ...
# 1534  haris.saif@erp-center.com  2024-09-14  None   Open         0
# 1535  haris.saif@erp-center.com  2024-09-14  None   Open         0
# 1536  haris.saif@erp-center.com  2024-09-14  None   Open         0
# 1537  haris.saif@erp-center.com  2024-09-14  None   Open         0
# 1538  haris.saif@erp-center.com  2024-09-14  None   Open         0
#
# [953 rows x 13 columns]

# %%
leads = pd.read_csv('/Users/harissaif/Downloads/ERP/Files/leads.csv')

# %%
leads['LeadID'] = np.arange(1000, 1000 + 10*leads.shape[0], 10)

# %%
leads
# Out:
#                   Company Name                              Position  \
# 0         S&C Electric Company             Chief Information Officer
# 1         S&C Electric Company               Chief Operating Officer
# 2         S&C Electric Company                         VP Operations
# 3     Bob's Discount Furniture             Chief Information Officer
# 4     Bob's Discount Furniture  Senior Director, Business Technology
# ...                        ...                                   ...
# 1559               Voith Hydro                    Technical Director
# 1560               Voith Hydro                     Technical manager
# 1561                    TRILUX                     Head of Solutions
# 1562                    TRILUX                       Leiter Group IT
# 1563                    TRILUX              Chief Technology Officer
#
#      First Name   Last Name                       Email  LeadID
# 0           Bob        King          bob.king@sandc.com    1000
# 1           Jim     Johnson               jim@sandc.com    1010
# 2       Anthony      Bezina    anthony.bezina@sandc.com    1020
# 3          Adam        Kuta            akuta@mybobs.com    1030
# 4         Irene   Valentine  irene.valentine@mybobs.com    1040
# ...         ...         ...                         ...     ...
# 1559     Pirkle        Mark                         NaN   16590
# 1560     Gunnar      Bakken                         NaN   16600
# 1561      Kamil           K                         NaN   16610
# 1562     Stefan  Magerstedt                         NaN   16620
# 1563  Sebastian    Traegner                         NaN   16630
#
# [1564 rows x 6 columns]
